# %% [markdown]
# <h2 align="center">
# <font color='green'>    Vale3 - Stock Analisys - Data Preparation</font></h2>   <img src=logo-vale-escudo-256.png style="float: left; width:80px; height:80px;" />
#
#
# <h4 align="center"><font color='gray'>Data Preparation - Capture vale3 informationa from different sources, different periodicities to create a consistent data repositorie that will support the different algothms</font></h4>

# %% [markdown]
# <h4> <align="center"><font color='orange'> Index : </font></h4>
#
#
# - [0 - Librarys](#0)
# - [1 - Functions](#1)
# - [2 - Daily Stock Prices](#2)
# - [3 - Dividends](#3)
# - [4 - JSCP](#5)
# - [5 - SP500](#6)
# - [6 - Income Information](#7)
# - [7 - Balance Information](#8)
# - [12 - Graficos e Analises](#9)

# %% [markdown]
# <h4> <align="center"><font color='yellow'> Ajustes no código : </font></h4>
#
# - Passamos a deixar a data como índice em todos os arquivos
# - passamos a extrair as informações de dividendos diretamente no YFinance, sem upload de arquivo

# %% [markdown]
#  ### 0 - Librarys

# %%
# Importando as bibliotecas necessárias

import yfinance as yf
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns

# Configuranco o periodo de extração das informações
# 

start = '2008-01-01'
end = '2023-10-31'

# %% [markdown]
# ### 1 - Functions

# %%
# funcao para extrair informacoes do income
def extract_financial_info(year, column_name, dataframe):
    """
    Função para extrair informações financeiras de um DataFrame com base no ano e no nome da coluna.
    
    Parâmetros:
    - year (str): Ano para o qual a informação deve ser extraída.
    - column_name (str): Nome da coluna (informação financeira) que se deseja extrair.
    - dataframe (pd.DataFrame): DataFrame contendo os dados financeiros.
    
    Retorna:
    - Valor da informação financeira para o ano especificado.
    """
    try:
        value = income[year][column_name]
        return value
    except KeyError:
        return f'Informação {column_name} para o ano {year} não encontrada.'
    except Exception as e:
        return f'Erro ao extrair informação: {e}'

# %%
def inserir_income(df, EBITDA, valor, atualizar=False):
  """
  Insere informações do balanço, que tem periodicidade anual, no arquivo da vale que .

  Args:
    df: O DataFrame no qual a coluna será inserida.
    nome_coluna: O nome da coluna a ser inserida.
    valor: O valor a ser inserido na coluna.
    atualizar: Se True, o valor será atualizado na coluna se ela já existir. Se False, a coluna será criada se não existir.

  Returns:
    O DataFrame com a coluna inserida.
  """

  # Verifica se a coluna já existe

  if nome_coluna in df.columns:
    # Atualiza o valor da coluna
    if atualizar:
      df[nome_coluna] = valor
    else:
      raise ValueError(f"A coluna '{nome_coluna}' já existe. Use atualizar=True para atualizar o valor da coluna.")
  else:
    # Cria a coluna
    df[nome_coluna] = valor

  return df

# %%
def nulls_to_zero(df):
    """
    Substitui valores nulos em um DataFrame do pandas por zero.
    
    Args:
    - df (pd.DataFrame): DataFrame de entrada.


    Returns:
    - pd.DataFrame: DataFrame com valores nulos substituídos por zero.
    - str: Mensagem informando a quantidade de valores convertidos ou um erro.
    """
    try:
        # Contando a quantidade de valores nulos antes da substituição
        null_count = df.isnull().sum().sum()
        
        # Substituindo valores nulos por zero
        df.fillna(0, inplace=True)
        
        message = f"{null_count} valores nulos foram substituídos por zero."
        return df, message
    except Exception as e:
        return df, f"Ocorreu um erro: {str(e)}"

# %%
# Verificando linhas duplicadas em um determinado arquivo txt, csv, etc
def file_linhas_duplicadas(filename):
    try:
        with open(filename, 'r', encoding='utf-8') as file:
            lines = file.readlines()
    except Exception as e:
        print(f"An error occurred: {e}")
        return None
    
    line_counts = {}  # Dicionário para armazenar a contagem de cada linha
    for line in lines:
        line = line.strip()  # Removendo espaços em branco no início e no fim
        line_counts[line] = line_counts.get(line, 0) + 1  # Incrementando a contagem
    
    # Calculando o número de linhas duplicadas
    duplicate_lines_count = sum(count - 1 for count in line_counts.values() if count > 1)
    
    return duplicate_lines_count

# %%
"""
    Esta função verifica se um DataFrame tem linhas duplicadas.
    
    Parâmetros:
    df (pandas.DataFrame): O DataFrame a ser verificado.
    
    Retorno:
    int: O número de linhas duplicadas no DataFrame.
"""

def df_linhas_duplicadas(df):
   
    linhas_duplicadas = df.duplicated().sum()
    return linhas_duplicadas

# %%
def verifica_nulos(df):
    """
    Esta função verifica se um DataFrame tem informações nulas.
    
    Parâmetros:
    df (pandas.DataFrame): O DataFrame a ser verificado.
    
    Retorno:
    pandas.DataFrame ou str: As linhas com informações nulas ou uma mensagem indicando que não há nulos.
    """
    # Verifica se há alguma célula nula no DataFrame
    if df.isnull().values.any():
        # Retorna as linhas que têm algum valor nulo
        linhas_nulas = df[df.isnull().any(axis=1)]
        return linhas_nulas
    else:
        # Retorna uma mensagem indicando que não há valores nulos
        return "Não existem valores nulos no DataFrame."

# Exemplo de uso:
# Suponha que df seja o DataFrame que você quer verificar.
# resultado = verifica_nulos(df)
# print(resultado)

# %%
# Funcao para gerar um arquivo csv para alimentar os diversos modelos que serao utilizados
# no projeto

def gera_csv(df, nome_arquivo='dados.csv'):
    """
    Esta função recebe um DataFrame pandas como parâmetro e gera um arquivo CSV.
    
    Parâmetros:
    df (pandas.DataFrame): O DataFrame a ser convertido em CSV.
    nome_arquivo (str): O nome do arquivo CSV a ser gerado. O padrão é 'dados.csv'.
    
    Retorno:
    str: Uma mensagem indicando sucesso ou falha na geração do arquivo CSV.
    """
    try:
        # Gera o arquivo CSV
        df.to_csv(nome_arquivo, index=False)
        return f'Arquivo {nome_arquivo} gerado com sucesso.'
    except Exception as e:
        # Retorna uma mensagem de erro se algo der errado
        return f'Ocorreu um erro ao gerar o arquivo CSV: {str(e)}'

# Exemplo de uso:
# Suponha que df seja o DataFrame que você quer converter em CSV.
# mensagem = gera_csv(df, 'meu_arquivo.csv')
# print(mensagem)

# %%
def inserir_income(df, EBITDA, valor, atualizar=False):
  """
  Insere informações do balanço, que tem periodicidade anual, no arquivo da vale que .

  Args:
    df: O DataFrame no qual a coluna será inserida.
    nome_coluna: O nome da coluna a ser inserida.
    valor: O valor a ser inserido na coluna.
    atualizar: Se True, o valor será atualizado na coluna se ela já existir. Se False, a coluna será criada se não existir.

  Returns:
    O DataFrame com a coluna inserida.
  """

  # Verifica se a coluna já existe

  if nome_coluna in df.columns:
    # Atualiza o valor da coluna
    if atualizar:
      df[nome_coluna] = valor
    else:
      raise ValueError(f"A coluna '{nome_coluna}' já existe. Use atualizar=True para atualizar o valor da coluna.")
  else:
    # Cria a coluna
    df[nome_coluna] = valor

  return df

# %% [markdown]
#  ### 2 - Daily Stock Prices

# %% [markdown]
# <hr>
# <p> data = 07/11/2023 </p>
# <p> - Foram extraidas informaçoes de 3 fontes de dados, foi utilizado o comando parse_date e set_index, para criar as datas como indice e fazer o merge dos arquivos
# <p> - Foram trabalhadas as informacoes de nulos
#
#
#  </p>
# <hr>

# %%
# Definindo a ativo que vamos extrair informações
#
symbol = 'vale3.sa'

# %%
# get historical market data
vale = yf.download(symbol, start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
vale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3930 entries, 2008-01-02 to 2023-10-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3930 non-null   float64
#  1   High       3930 non-null   float64
#  2   Low        3930 non-null   float64
#  3   Close      3930 non-null   float64
#  4   Adj Close  3930 non-null   float64
#  5   Volume     3930 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 214.9 KB

# %%
# a data ficou formatada com HH:MM:SS, ficou ruim de trabalhar nas queries
vale.head(2)
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2008-01-02  59.250000  59.290001  57.549999  57.900002  26.739397  1200600
# 2008-01-03  58.060001  58.860001  57.889999  58.200001  26.877935  1114700

# %%
############################################################################################
# Deleting some columns from the dataframe
############################################################################################
del vale['Open']
del vale['High']    
del vale['Low']
del vale['Adj Close'] 
del vale['Volume'] 

vale.head()
# Out:
#                 Close
# Date
# 2008-01-02  57.900002
# 2008-01-03  58.200001
# 2008-01-04  56.099998
# 2008-01-07  55.099998
# 2008-01-08  56.200001

# %%
######################################################################################################
# Grafico em cima do preco de fechamento 'Close'                                                                #
# dataCom(NEGOCIADO ATÉ) - ate esta data quem estiver com o papel em carteira vai receber dividendos  #
#                                                                                                     #
#######################################################################################################

plt.figure(figsize=(14, 7))
plt.plot(vale.index, vale['Close'], label='Close', color='blue')
plt.title('Gráfico de Linha - Close x Date')
plt.xlabel('Date')
plt.ylabel('Close')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# <p> <align="center"><font color='white'>Creating a new columns 'tomorrow' and 'target' to help in the prediction process</font></p>

# %%
# queremos mostrar se existe uma tendencia de alta, para isto vamos criar uma coluna 'tomorrow', vamos prever o amanha
# vamos utilizar o metodo shift do Pandas

vale['Tomorrow'] = vale['Close'].shift(-1)

# %%
vale.head(2)
# Out:
#                 Close   Tomorrow
# Date
# 2008-01-02  57.900002  58.200001
# 2008-01-03  58.200001  56.099998

# %%
# queremos prever que tomorrow's price seja maior que today's price
# tambem vamos converter os campos para inteiro usando a funcao astype(int)
vale['Target'] = (vale['Tomorrow'] > vale['Close']).astype(int)

# %%
vale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3930 entries, 2008-01-02 to 2023-10-30
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Close     3930 non-null   float64
#  1   Tomorrow  3929 non-null   float64
#  2   Target    3930 non-null   int32
# dtypes: float64(2), int32(1)
# memory usage: 107.5 KB

# %% [markdown]
# ### 3 -  Dividends: Loading Data from YFinance
# <hr>

# %%
# vamos extrair as informaçoes utilizando o metodo ticker

dividendos = yf.Ticker("vale3.sa")

# %%
# Extraindo as informações da API
# Periodo 
# start = 
dividendos = yf.download(symbol, start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dividendos.head(2)
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2008-01-02  59.250000  59.290001  57.549999  57.900002  26.739395  1200600
# 2008-01-03  58.060001  58.860001  57.889999  58.200001  26.877943  1114700

# %%
# deletando as informações que nao serao utilizadas

del dividendos['Open'] 
del dividendos['High'] 
del dividendos['Low']
del dividendos['Volume']
del dividendos['Adj Close'] 

# Renomendo o close
dividendos.rename(columns={
    'Close': 'Dividends'
    }, inplace=True)

# Verificando o Aquivo
dividendos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3930 entries, 2008-01-02 to 2023-10-30
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Dividends  3930 non-null   float64
# dtypes: float64(1)
# memory usage: 61.4 KB

# %%
# Merge the 'Aprovado' information into your DataFrame
#vale_div = vale.merge(dividendos[['Dividends']], left_index=True, right_on='Dividends', how='left')
#df_merged = df1.merge(df2, left_index=True, right_index=True, how='inner')


vale_d = vale.merge(dividendos, left_index=True, right_index=True, how='left')

vale_d.head(2)
# Out:
#                 Close   Tomorrow  Target  Dividends
# Date
# 2008-01-02  57.900002  58.200001       1  57.900002
# 2008-01-03  58.200001  56.099998       0  58.200001

# %%
vale_d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3930 entries, 2008-01-02 to 2023-10-30
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Close      3930 non-null   float64
#  1   Tomorrow   3929 non-null   float64
#  2   Target     3930 non-null   int32
#  3   Dividends  3930 non-null   float64
# dtypes: float64(3), int32(1)
# memory usage: 267.2 KB

# %%
vale_d[vale_d.index == '2018-08-03']
# Out:
#                 Close   Tomorrow  Target  Dividends
# Date
# 2018-08-03  52.549999  52.400002       0  52.549999

# %% [markdown]
# ### 4 - JCSP

# %% [markdown]
#  <p style="font-size: 16px;">Loading, cleaning and quality check for JCSP information !</p>
#  <p style="font-size: 12px;">Source: YFinance</p>
#  <p style="font-size: 12px;">Type: File extracted Manually</p>
#  <p style="font-size: 12px;">Obs. Choose file against API because the format were more suitable for the stretegy</p>

# %%
#######################################################################################################
# Carregando informacoes de JSCP	                                                              #
# dataCom(NEGOCIADO ATÉ) - ate esta data quem estiver com o papel em carteira vai receber dividendos  #
# APROVADO - data de aprovacao do pagamento do dividendo                                              #
# VALOR (R$) - Valor por acao que sera pago apurado conforme balanco                                  #
#######################################################################################################

JSCP = pd.read_csv('Vale3-ProventosGeral.csv', parse_dates=['APROVADO'], index_col='APROVADO')
JSCP
# Out:
# C:\Users\edmun\AppData\Local\Temp\ipykernel_20252\2487070507.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   JSCP = pd.read_csv('Vale3-ProventosGeral.csv', parse_dates=['APROVADO'], index_col='APROVADO')
#                      TIPO   VALOR (R$) % / FATOR VALOR EMISSÃO (R$)  \
# APROVADO
# 2023-07-27           JSCP         1,91       n/d                n/d
# 2023-02-16      Dividendo         1,82       n/d                n/d
# 2022-01-12           JSCP  0,290809381       n/d                n/d
# 2022-07-28      Dividendo         2,03       n/d                n/d
# 2022-07-28           JSCP         1,53       n/d                n/d
# 2022-02-24      Dividendo         3,71       n/d                n/d
# 2021-09-16      Dividendo         8,19       n/d                n/d
# 2021-06-17      Dividendo  0,716268047       n/d                n/d
# 2021-06-17      Dividendo         1,46       n/d                n/d
# 2021-02-25      Dividendo         3,42       n/d                n/d
# 2021-02-25           JSCP  0,835736883       n/d                n/d
# 2020-10-09      Dividendo         1,41       n/d                n/d
# 2020-10-09           JSCP  0,997344547       n/d                n/d
# 2019-12-19           JSCP         1,41       n/d                n/d
# 2018-07-25      Dividendo  0,171747417       n/d                n/d
# 2007-08-31  Desdobramento          n/d    100,00                n/d
# 1997-04-18    Bonificação          n/d    100,00                n/d
# 1996-10-04     Grupamento          n/d      0,10                n/d
# 1991-10-07     Subscrição          n/d      0,00            1222000
#
#            NEGOCIADO ATÉ PAGAMENTO
# APROVADO
# 2023-07-27      11/08/23  01/09/23
# 2023-02-16      13/03/23  22/03/23
# 2022-01-12      12/12/22       n/d
# 2022-07-28      11/08/22  01/09/22
# 2022-07-28      11/08/22  01/09/22
# 2022-02-24      08/03/22  16/03/22
# 2021-09-16      22/09/21  30/09/21
# 2021-06-17      23/06/21  30/06/21
# 2021-06-17      23/06/21  30/06/21
# 2021-02-25      04/03/21  15/03/21
# 2021-02-25      04/03/21  15/03/21
# 2020-10-09      21/09/20  30/09/20
# 2020-10-09      21/09/20  30/09/20
# 2019-12-19      26/12/19       n/d
# 2018-07-25      02/08/18  20/09/18
# 2007-08-31      31/08/07       n/d
# 1997-04-18      18/04/97       n/d
# 1996-10-04      10/04/96       n/d
# 1991-10-07      26/07/91       n/d

# %%
JSCP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19 entries, 2023-07-27 to 1991-10-07
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   TIPO                19 non-null     object
#  1   VALOR (R$)          19 non-null     object
#  2   % / FATOR           19 non-null     object
#  3   VALOR EMISSÃO (R$)  19 non-null     object
#  4   NEGOCIADO ATÉ       19 non-null     object
#  5   PAGAMENTO           19 non-null     object
# dtypes: object(6)
# memory usage: 1.0+ KB

# %%
# criando um data frame com as informacoes de JSCP apenas
JSCP = JSCP[JSCP['TIPO'] == 'JSCP']
JSCP
# Out:
#             TIPO   VALOR (R$) % / FATOR VALOR EMISSÃO (R$) NEGOCIADO ATÉ  \
# APROVADO
# 2023-07-27  JSCP         1,91       n/d                n/d      11/08/23
# 2022-01-12  JSCP  0,290809381       n/d                n/d      12/12/22
# 2022-07-28  JSCP         1,53       n/d                n/d      11/08/22
# 2021-02-25  JSCP  0,835736883       n/d                n/d      04/03/21
# 2020-10-09  JSCP  0,997344547       n/d                n/d      21/09/20
# 2019-12-19  JSCP         1,41       n/d                n/d      26/12/19
#
#            PAGAMENTO
# APROVADO
# 2023-07-27  01/09/23
# 2022-01-12       n/d
# 2022-07-28  01/09/22
# 2021-02-25  15/03/21
# 2020-10-09  30/09/20
# 2019-12-19       n/d

# %% [markdown]
# <p> <font color='red'> Tirando as linhas com n/d, basicamente são da data de pagamento 2 linhas</p>

# %%
JSCP[JSCP['VALOR EMISSÃO (R$)'] == 'n/d']
# Out:
#             TIPO   VALOR (R$) % / FATOR VALOR EMISSÃO (R$) NEGOCIADO ATÉ  \
# APROVADO
# 2023-07-27  JSCP         1,91       n/d                n/d      11/08/23
# 2022-01-12  JSCP  0,290809381       n/d                n/d      12/12/22
# 2022-07-28  JSCP         1,53       n/d                n/d      11/08/22
# 2021-02-25  JSCP  0,835736883       n/d                n/d      04/03/21
# 2020-10-09  JSCP  0,997344547       n/d                n/d      21/09/20
# 2019-12-19  JSCP         1,41       n/d                n/d      26/12/19
#
#            PAGAMENTO
# APROVADO
# 2023-07-27  01/09/23
# 2022-01-12       n/d
# 2022-07-28  01/09/22
# 2021-02-25  15/03/21
# 2020-10-09  30/09/20
# 2019-12-19       n/d

# %%
JSCP = JSCP.drop(pd.Timestamp('2022-01-12'))

# %%
JSCP = JSCP.drop(pd.Timestamp('2019-12-19'))

# %%
JSCP[JSCP['PAGAMENTO'] == 'n/d']
# Out:
# Empty DataFrame
# Columns: [TIPO, VALOR (R$), % / FATOR, VALOR EMISSÃO (R$), NEGOCIADO ATÉ, PAGAMENTO]
# Index: []

# %%
# Deletando as colunas que nao vamos utilizar
del JSCP['TIPO']
del JSCP['% / FATOR']
del JSCP['VALOR EMISSÃO (R$)']

JSCP
# Out:
#              VALOR (R$) NEGOCIADO ATÉ PAGAMENTO
# APROVADO
# 2023-07-27         1,91      11/08/23  01/09/23
# 2022-07-28         1,53      11/08/22  01/09/22
# 2021-02-25  0,835736883      04/03/21  15/03/21
# 2020-10-09  0,997344547      21/09/20  30/09/20

# %%
############################################################################################
# Convertendo a coluna 'data_obj' para datetime no formato do indice do arquivo dividendos #
# para deixar no mesmo formato dos campos do arquivo de vale                               #
############################################################################################

#JSCP['PAGAMENTO'] = pd.to_datetime(JSCP['PAGAMENTO'], format='%d/%m/%y')
JSCP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4 entries, 2023-07-27 to 2020-10-09
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   VALOR (R$)     4 non-null      object
#  1   NEGOCIADO ATÉ  4 non-null      object
#  2   PAGAMENTO      4 non-null      object
# dtypes: object(3)
# memory usage: 128.0+ bytes

# %%
# Renomenado a coluna para jscpDataCom
JSCP.rename(columns={
    'VALOR (R$)': 'jscpValor',
    'NEGOCIADO ATÉ': 'jscpDataCom',
    'PAGAMENTO': 'jscpPagamento'
    }, inplace=True)
JSCP
# Out:
#               jscpValor jscpDataCom jscpPagamento
# APROVADO
# 2023-07-27         1,91    11/08/23      01/09/23
# 2022-07-28         1,53    11/08/22      01/09/22
# 2021-02-25  0,835736883    04/03/21      15/03/21
# 2020-10-09  0,997344547    21/09/20      30/09/20

# %%
vale_d.head(2)
# Out:
#                 Close   Tomorrow  Target  Dividends
# Date
# 2008-01-02  57.900002  58.200001       1  57.900002
# 2008-01-03  58.200001  56.099998       0  58.200001

# %%
# Merge the 'Aprovado' information into your DataFrame

vale_dj = vale_d.merge(JSCP, left_index=True, right_index=True, how='left')
vale_dj.head()
# Out:
#                 Close   Tomorrow  Target  Dividends jscpValor jscpDataCom  \
# Date
# 2008-01-02  57.900002  58.200001       1  57.900002       NaN         NaN
# 2008-01-03  58.200001  56.099998       0  58.200001       NaN         NaN
# 2008-01-04  56.099998  55.099998       0  56.099998       NaN         NaN
# 2008-01-07  55.099998  56.200001       1  55.099998       NaN         NaN
# 2008-01-08  56.200001  55.599998       0  56.200001       NaN         NaN
#
#            jscpPagamento
# Date
# 2008-01-02           NaN
# 2008-01-03           NaN
# 2008-01-04           NaN
# 2008-01-07           NaN
# 2008-01-08           NaN

# %%
vale_dj[vale_dj.index == '2023-07-27']
# Out:
#                 Close   Tomorrow  Target  Dividends jscpValor jscpDataCom  \
# Date
# 2023-07-27  70.419998  67.629997       0  70.419998      1,91    11/08/23
#
#            jscpPagamento
# Date
# 2023-07-27      01/09/23

# %%
#####################################################################
# Convertendo o NaT para 0 e o valor de data para 1                 # 
#####################################################################
# sugestao do chatgpt para resolver o problema
#
vale_dj['Dividends'] = vale_dj['Dividends'].notna().astype(int)
vale_dj['jscpValor'] = vale_dj['jscpValor'].notna().astype(int)
vale_dj['jscpDataCom'] = vale_dj['jscpDataCom'].notna().astype(int)
vale_dj['jscpPagamento'] = vale_dj['jscpPagamento'].notna().astype(int)
vale_dj.head()
# Out:
#                 Close   Tomorrow  Target  Dividends  jscpValor  jscpDataCom  \
# Date
# 2008-01-02  57.900002  58.200001       1          1          0            0
# 2008-01-03  58.200001  56.099998       0          1          0            0
# 2008-01-04  56.099998  55.099998       0          1          0            0
# 2008-01-07  55.099998  56.200001       1          1          0            0
# 2008-01-08  56.200001  55.599998       0          1          0            0
#
#             jscpPagamento
# Date
# 2008-01-02              0
# 2008-01-03              0
# 2008-01-04              0
# 2008-01-07              0
# 2008-01-08              0

# %%
verifica_nulos(vale_dj)
# Out:
#             Close  Tomorrow  Target  Dividends  jscpValor  jscpDataCom  \
# Date
# 2023-10-30  68.18       NaN       0          1          0            0
#
#             jscpPagamento
# Date
# 2023-10-30              0

# %%
# Deletando a linha com tomorrow = NaN
vale_dj = vale_dj.drop(pd.Timestamp('2023-10-30'))

# %% [markdown]
# <h4> <font color='red'> Deletando a Informaçao de Volume que está trazendo um dado enviazado que pode atrapalhar o algoritmo</h4>

# %% [markdown]
# ### 5 - S&P500

# %%
# Definindo o ativo
symbol = '^GSPC'

# %%
# get historical market data
sp500 = yf.download(symbol, start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
sp500.head(3)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2008-01-02  1467.969971  1471.770020  1442.069946  1447.160034  1447.160034
# 2008-01-03  1447.550049  1456.800049  1443.729980  1447.160034  1447.160034
# 2008-01-04  1444.010010  1444.010010  1411.189941  1411.630005  1411.630005
#
#                 Volume
# Date
# 2008-01-02  3452650000
# 2008-01-03  3429500000
# 2008-01-04  4166000000

# %%
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3985 entries, 2008-01-02 to 2023-10-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3985 non-null   float64
#  1   High       3985 non-null   float64
#  2   Low        3985 non-null   float64
#  3   Close      3985 non-null   float64
#  4   Adj Close  3985 non-null   float64
#  5   Volume     3985 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 217.9 KB

# %%
############################################################################################
# Deleting some columns from the dataframe
############################################################################################
del sp500['Open']
del sp500['High']    
del sp500['Low']
del sp500['Adj Close'] 
del sp500['Volume'] 

sp500.head(2)
# Out:
#                   Close
# Date
# 2008-01-02  1447.160034
# 2008-01-03  1447.160034

# %%
# Renomenado a coluna para sp500
sp500.rename(columns={
    'Close': 'sp500'
    }, inplace=True)
sp500.head(2)
# Out:
#                   sp500
# Date
# 2008-01-02  1447.160034
# 2008-01-03  1447.160034

# %%
# Merge the 'Aprovado' information into your DataFrame

vale_dj = vale_dj.merge(sp500, left_index=True, right_index=True, how='left')
vale_dj.head()
# Out:
#                 Close   Tomorrow  Target  Dividends  jscpValor  jscpDataCom  \
# Date
# 2008-01-02  57.900002  58.200001       1          1          0            0
# 2008-01-03  58.200001  56.099998       0          1          0            0
# 2008-01-04  56.099998  55.099998       0          1          0            0
# 2008-01-07  55.099998  56.200001       1          1          0            0
# 2008-01-08  56.200001  55.599998       0          1          0            0
#
#             jscpPagamento        sp500
# Date
# 2008-01-02              0  1447.160034
# 2008-01-03              0  1447.160034
# 2008-01-04              0  1411.630005
# 2008-01-07              0  1416.180054
# 2008-01-08              0  1390.189941

# %%
# exportando o modelo para rodar os algoritmos
gera_csv(vale, nome_arquivo='vale_dj.csv', )
# Out:
# 'Arquivo vale_dj.csv gerado com sucesso.'

# %% [markdown]
# ### 6 - Dolar Comercial

# %%
# Definindo o ativo
symbol = "USDBRL=X"

# %%
# get historical market data
dolar = yf.download(symbol, start, end)
dolar
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                Open    High       Low    Close  Adj Close  Volume
# Date
# 2008-01-01  1.76730  1.7673  1.767300  1.76730    1.76730       0
# 2008-01-02  1.77600  1.7822  1.756000  1.76450    1.76450       0
# 2008-01-03  1.76450  1.7684  1.748000  1.74800    1.74800       0
# 2008-01-04  1.74800  1.7665  1.739100  1.75720    1.75720       0
# 2008-01-07  1.76150  1.7777  1.745100  1.76400    1.76400       0
# ...             ...     ...       ...      ...        ...     ...
# 2023-10-24  5.01230  5.0261  4.971456  5.01230    5.01230       0
# 2023-10-25  4.99100  5.0165  4.985900  4.99100    4.99100       0
# 2023-10-26  4.99470  5.0148  4.986613  4.99470    4.99470       0
# 2023-10-27  4.98530  4.9874  4.930200  4.98530    4.98530       0
# 2023-10-30  4.95203  5.0478  4.952030  4.95203    4.95203       0
#
# [4100 rows x 6 columns]

# %%
############################################################################################
# Deleting some columns from the dataframe
############################################################################################
del dolar['Open']
del dolar['High']    
del dolar['Low']
del dolar['Adj Close'] 
del dolar['Volume'] 

dolar.head(2)
# Out:
#              Close
# Date
# 2008-01-01  1.7673
# 2008-01-02  1.7645

# %%
# Renomenado a coluna para sp500
dolar.rename(columns={
    'Close': 'US$Comercial'
    }, inplace=True)
dolar.head(2)
# Out:
#             US$Comercial
# Date
# 2008-01-01        1.7673
# 2008-01-02        1.7645

# %%
dolar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4100 entries, 2008-01-01 to 2023-10-30
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   US$Comercial  4100 non-null   float64
# dtypes: float64(1)
# memory usage: 64.1 KB

# %%
# Merge the 'Aprovado' information into your DataFrame

vale_djus = vale_dj.merge(dolar, left_index=True, right_index=True, how='left')
vale_djus.head()
# Out:
#                 Close   Tomorrow  Target  Dividends  jscpValor  jscpDataCom  \
# Date
# 2008-01-02  57.900002  58.200001       1          1          0            0
# 2008-01-03  58.200001  56.099998       0          1          0            0
# 2008-01-04  56.099998  55.099998       0          1          0            0
# 2008-01-07  55.099998  56.200001       1          1          0            0
# 2008-01-08  56.200001  55.599998       0          1          0            0
#
#             jscpPagamento        sp500
# Date
# 2008-01-02              0  1447.160034
# 2008-01-03              0  1447.160034
# 2008-01-04              0  1411.630005
# 2008-01-07              0  1416.180054
# 2008-01-08              0  1390.189941

# %%
vale_djus.head()
# Out:
#                 Close   Tomorrow  Target  Dividends  jscpValor  jscpDataCom  \
# Date
# 2008-01-02  57.900002  58.200001       1          1          0            0
# 2008-01-03  58.200001  56.099998       0          1          0            0
# 2008-01-04  56.099998  55.099998       0          1          0            0
# 2008-01-07  55.099998  56.200001       1          1          0            0
# 2008-01-08  56.200001  55.599998       0          1          0            0
#
#             jscpPagamento        sp500  US$Comercial
# Date
# 2008-01-02              0  1447.160034        1.7645
# 2008-01-03              0  1447.160034        1.7480
# 2008-01-04              0  1411.630005        1.7572
# 2008-01-07              0  1416.180054        1.7640
# 2008-01-08              0  1390.189941        1.7520

# %%
verifica_nulos(vale_djus)
# Out:
#                 Close   Tomorrow  Target  Dividends  jscpValor  jscpDataCom  \
# Date
# 2008-01-21  46.220001  47.599998       1          1          0            0
# 2008-02-18  57.590000  57.910000       1          1          0            0
# 2008-04-01  61.750000  61.099998       0          1          0            0
# 2008-05-26  67.500000  66.190002       0          1          0            0
# 2008-07-01  55.009998  52.189999       0          1          0            0
# ...               ...        ...     ...        ...        ...          ...
# 2023-01-16  92.250000  92.129997       0          1          0            0
# 2023-05-29  65.830002  64.279999       0          1          0            0
# 2023-06-19  69.400002  67.610001       0          1          0            0
# 2023-07-04  65.900002  65.320000       0          1          0            0
# 2023-09-04  69.400002  69.099998       0          1          0            0
#
#             jscpPagamento        sp500  US$Comercial
# Date
# 2008-01-21              0          NaN        1.8262
# 2008-02-18              0          NaN        1.7325
# 2008-04-01              0  1370.180054           NaN
# 2008-05-26              0          NaN        1.6596
# 2008-07-01              0  1284.910034           NaN
# ...                   ...          ...           ...
# 2023-01-16              0          NaN        5.0807
# 2023-05-29              0          NaN        4.9928
# 2023-06-19              0          NaN        4.8070
# 2023-07-04              0          NaN        4.8065
# 2023-09-04              0          NaN        4.9763
#
# [126 rows x 9 columns]

# %%
# retirar os nulos do arquivo

# %% [markdown]
# ### 6 - Income

# %%
# get historical market data
vale3 = yf.Ticker("vale3.sa")

# %%
# get historical market data
hist = vale3.history(period="max")

# %%
income = vale3.income_stmt
income
# Out:
#                                                        2022-12-31  \
# Tax Effect Of Unusual Items                           334050000.0
# Tax Rate For Calcs                                           0.15
# Normalized EBITDA                                   21619000000.0
# Total Unusual Items                                  2227000000.0
# Total Unusual Items Excluding Goodwill               2227000000.0
# Net Income From Continuing Operation Net Minori...  16728000000.0
# Reconciled Depreciation                              3171000000.0
# Reconciled Cost Of Revenue                          20898000000.0
# EBITDA                                              23846000000.0
# EBIT                                                20675000000.0
# Net Interest Income                                  -536000000.0
# Interest Expense                                      894000000.0
# Interest Income                                       659000000.0
# Normalized Income                                   14835050000.0
# Net Income From Continuing And Discontinued Ope...  18788000000.0
# Total Expenses                                      26054000000.0
# Total Operating Income As Reported                  17208000000.0
# Diluted Average Shares                               4642432000.0
# Basic Average Shares                                 4637794000.0
# Diluted EPS                                                  4.05
# Basic EPS                                                    4.05
# Diluted NI Availto Com Stockholders                 18788000000.0
# Net Income Common Stockholders                      18788000000.0
# Net Income                                          18788000000.0
# Minority Interests                                    -82000000.0
# Net Income Including Noncontrolling Interests       18870000000.0
# Net Income Discontinuous Operations                  2060000000.0
# Net Income Continuous Operations                    16810000000.0
# Tax Provision                                        2971000000.0
# Pretax Income                                       19781000000.0
# Other Income Expense                                 2532000000.0
# Other Non Operating Income Expenses                           NaN
# Special Income Charges                               -577000000.0
# Gain On Sale Of Ppe                                   -46000000.0
# Other Special Charges                                1304000000.0
# Impairment Of Capital Assets                         -773000000.0
# Earnings From Equity Interest                         305000000.0
# Gain On Sale Of Security                             2804000000.0
# Net Non Operating Interest Income Expense            -536000000.0
# Total Other Finance Cost                              301000000.0
# Interest Expense Non Operating                        894000000.0
# Interest Income Non Operating                         659000000.0
# Operating Income                                    17785000000.0
# Operating Expense                                    2026000000.0
# Other Operating Expenses                              851000000.0
# Depreciation Amortization Depletion Income Stat...     41000000.0
# Depreciation And Amortization In Income Statement      41000000.0
# Research And Development                              660000000.0
# Selling General And Administration                    474000000.0
# Selling And Marketing Expense                         108000000.0
# General And Administrative Expense                    366000000.0
# Other Gand A                                          181000000.0
# Salaries And Wages                                    185000000.0
# Gross Profit                                        19811000000.0
# Cost Of Revenue                                     24028000000.0
# Total Revenue                                       43839000000.0
# Operating Revenue                                   43839000000.0
#
#                                                             2021-12-31  \
# Tax Effect Of Unusual Items                           284290850.005078
# Tax Rate For Calcs                                            0.158999
# Normalized EBITDA                                        32232000000.0
# Total Unusual Items                                       1788000000.0
# Total Unusual Items Excluding Goodwill                    1788000000.0
# Net Income From Continuing Operation Net Minori...       24821000000.0
# Reconciled Depreciation                                   3034000000.0
# Reconciled Cost Of Revenue                               18737000000.0
# EBITDA                                                   34020000000.0
# EBIT                                                     30986000000.0
# Net Interest Income                                      -1818000000.0
# Interest Expense                                          1445000000.0
# Interest Income                                                    NaN
# Normalized Income                                   23317290850.005077
# Net Income From Continuing And Discontinued Ope...       22445000000.0
# Total Expenses                                           23660000000.0
# Total Operating Income As Reported                       27693000000.0
# Diluted Average Shares                                    5012424000.0
# Basic Average Shares                                      5012424000.0
# Diluted EPS                                                       4.47
# Basic EPS                                                         4.47
# Diluted NI Availto Com Stockholders                      22445000000.0
# Net Income Common Stockholders                           22445000000.0
# Net Income                                               22445000000.0
# Minority Interests                                         -23000000.0
# Net Income Including Noncontrolling Interests            22468000000.0
# Net Income Discontinuous Operations                      -2376000000.0
# Net Income Continuous Operations                         24844000000.0
# Tax Provision                                             4697000000.0
# Pretax Income                                            29541000000.0
# Other Income Expense                                       517000000.0
# Other Non Operating Income Expenses                       -126000000.0
# Special Income Charges                                   -3149000000.0
# Gain On Sale Of Ppe                                         -5000000.0
# Other Special Charges                                     2718000000.0
# Impairment Of Capital Assets                               426000000.0
# Earnings From Equity Interest                            -1271000000.0
# Gain On Sale Of Security                                  4937000000.0
# Net Non Operating Interest Income Expense                -1818000000.0
# Total Other Finance Cost                                   373000000.0
# Interest Expense Non Operating                            1445000000.0
# Interest Income Non Operating                                      NaN
# Operating Income                                         30842000000.0
# Operating Expense                                         1931000000.0
# Other Operating Expenses                                   901000000.0
# Depreciation Amortization Depletion Income Stat...          42000000.0
# Depreciation And Amortization In Income Statement           42000000.0
# Research And Development                                   549000000.0
# Selling General And Administration                         439000000.0
# Selling And Marketing Expense                              107000000.0
# General And Administrative Expense                         332000000.0
# Other Gand A                                               162000000.0
# Salaries And Wages                                         170000000.0
# Gross Profit                                             32773000000.0
# Cost Of Revenue                                          21729000000.0
# Total Revenue                                            54502000000.0
# Operating Revenue                                        54268000000.0
#
#                                                             2020-12-31  \
# Tax Effect Of Unusual Items                          -820732139.263433
# Tax Rate For Calcs                                            0.088147
# Normalized EBITDA                                        19953000000.0
# Total Unusual Items                                      -9311000000.0
# Total Unusual Items Excluding Goodwill                   -9311000000.0
# Net Income From Continuing Operation Net Minori...        4881000000.0
# Reconciled Depreciation                                   3234000000.0
# Reconciled Cost Of Revenue                               15854000000.0
# EBITDA                                                   10642000000.0
# EBIT                                                      7408000000.0
# Net Interest Income                                      -3207000000.0
# Interest Expense                                          2439000000.0
# Interest Income                                            375000000.0
# Normalized Income                                   13371267860.736567
# Net Income From Continuing And Discontinued Ope...        4881000000.0
# Total Expenses                                           21468000000.0
# Total Operating Income As Reported                       10843000000.0
# Diluted Average Shares                                    5129585000.0
# Basic Average Shares                                      5129585000.0
# Diluted EPS                                                       0.95
# Basic EPS                                                         0.95
# Diluted NI Availto Com Stockholders                       4881000000.0
# Net Income Common Stockholders                            4881000000.0
# Net Income                                                4881000000.0
# Minority Interests                                         350000000.0
# Net Income Including Noncontrolling Interests             4531000000.0
# Net Income Discontinuous Operations                                0.0
# Net Income Continuous Operations                          4531000000.0
# Tax Provision                                              438000000.0
# Pretax Income                                             4969000000.0
# Other Income Expense                                    -10374000000.0
# Other Non Operating Income Expenses                       -115000000.0
# Special Income Charges                                   -7707000000.0
# Gain On Sale Of Ppe                                        -25000000.0
# Other Special Charges                                     5439000000.0
# Impairment Of Capital Assets                              2243000000.0
# Earnings From Equity Interest                            -1063000000.0
# Gain On Sale Of Security                                 -1604000000.0
# Net Non Operating Interest Income Expense                -3207000000.0
# Total Other Finance Cost                                   768000000.0
# Interest Expense Non Operating                            2439000000.0
# Interest Income Non Operating                              375000000.0
# Operating Income                                         18550000000.0
# Operating Expense                                         2429000000.0
# Other Operating Expenses                                  1432000000.0
# Depreciation Amortization Depletion Income Stat...          49000000.0
# Depreciation And Amortization In Income Statement           49000000.0
# Research And Development                                   443000000.0
# Selling General And Administration                         505000000.0
# Selling And Marketing Expense                              105000000.0
# General And Administrative Expense                         400000000.0
# Other Gand A                                               176000000.0
# Salaries And Wages                                         224000000.0
# Gross Profit                                             20979000000.0
# Cost Of Revenue                                          19039000000.0
# Total Revenue                                            40018000000.0
# Operating Revenue                                        39721000000.0
#
#                                                            2019-12-31
# Tax Effect Of Unusual Items                        -2675034234.234234
# Tax Rate For Calcs                                           0.214414
# Normalized EBITDA                                       17233000000.0
# Total Unusual Items                                    -12476000000.0
# Total Unusual Items Excluding Goodwill                 -12476000000.0
# Net Income From Continuing Operation Net Minori...      -1683000000.0
# Reconciled Depreciation                                  3726000000.0
# Reconciled Cost Of Revenue                              21187000000.0
# EBITDA                                                   4757000000.0
# EBIT                                                     1031000000.0
# Net Interest Income                                     -3413000000.0
# Interest Expense                                         3806000000.0
# Interest Income                                           527000000.0
# Normalized Income                                   8117965765.765766
# Net Income From Continuing And Discontinued Ope...      -1683000000.0
# Total Expenses                                          23775000000.0
# Total Operating Income As Reported                       1319000000.0
# Diluted Average Shares                                   5100000000.0
# Basic Average Shares                                     5100000000.0
# Diluted EPS                                                     -0.33
# Basic EPS                                                       -0.33
# Diluted NI Availto Com Stockholders                     -1683000000.0
# Net Income Common Stockholders                          -1683000000.0
# Net Income                                              -1683000000.0
# Minority Interests                                        497000000.0
# Net Income Including Noncontrolling Interests           -2180000000.0
# Net Income Discontinuous Operations                               0.0
# Net Income Continuous Operations                        -2180000000.0
# Tax Provision                                            -595000000.0
# Pretax Income                                           -2775000000.0
# Other Income Expense                                   -13157000000.0
# Other Non Operating Income Expenses                       -89000000.0
# Special Income Charges                                 -12476000000.0
# Gain On Sale Of Ppe                                       -47000000.0
# Other Special Charges                                    7402000000.0
# Impairment Of Capital Assets                             5074000000.0
# Earnings From Equity Interest                            -681000000.0
# Gain On Sale Of Security                                  530000000.0
# Net Non Operating Interest Income Expense               -3413000000.0
# Total Other Finance Cost                                  134000000.0
# Interest Expense Non Operating                           3806000000.0
# Interest Income Non Operating                             527000000.0
# Operating Income                                        13795000000.0
# Operating Expense                                        2588000000.0
# Other Operating Expenses                                 1658000000.0
# Depreciation Amortization Depletion Income Stat...         56000000.0
# Depreciation And Amortization In Income Statement          56000000.0
# Research And Development                                  443000000.0
# Selling General And Administration                        487000000.0
# Selling And Marketing Expense                              92000000.0
# General And Administrative Expense                        339000000.0
# Other Gand A                                              158000000.0
# Salaries And Wages                                        181000000.0
# Gross Profit                                            16383000000.0
# Cost Of Revenue                                         21187000000.0
# Total Revenue                                           37570000000.0
# Operating Revenue                                       37570000000.0

# %%
#income['2022-12-31'].
# Out:
#   Cell In[69], line 1
#     income['2022-12-31'].
#                          ^
# SyntaxError: invalid syntax

# %%
EBITDA = extract_financial_info('2022-12-31', 'EBITDA', income)
EBITDA

# %%
# Criar a coluna 'Anual' com o primeiro valor de cada ano
df['Anual'] = df.groupby(df.index.year)['Close'].transform('first')

# %%
vale_dj.head(2)

# %% [markdown]
# Operating Revenue

# %% [markdown]
# ### 12 - Gráficos e Analises

# %%
vale_dj[vale_dj.index == '2023-08-11']

# %%
# tem que ajustar, esta errado

df_august_2022 = vale_dj[(vale_dj.index >= '2021-01-01') & (vale_dj.index <= '2022-08-30')]

df_dividends = df_august_2022[df_august_2022['Dividends'] != 0]

# 
# Plotando o gráfico de linha com duas linhas: 'Close' e 'Dividends'
plt.figure(figsize=(10, 6))
plt.plot(df_august_2022.index, df_august_2022['Close'], marker='o', linestyle='-', label='Close')
plt.scatter(df_dividends.index, df_dividends['Close'], color='red', label='Dividends', zorder=5)
plt.title('Preço de Fechamento e Dividendos em Agosto de 2022')
plt.xlabel('Data')
plt.ylabel('Preço de Fechamento')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#
# Finalizada a primeira faze que tinha como objetivo montar uma 
# estrutura de dados com informacoes de dividendos e jscp
#
correlation_matrix = vale_dj.corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Matriz de Correlação')
plt.show()

# %% [markdown]
# <p> <font color='grey'> Função para extrair informações do arquivo income</h4>
# <hr>

# %%
EBITDA = extract_financial_info('2022-12-31', 'EBITDA', income)
EBITDA

# %% [markdown]
# <p> <font color='grey'> Insere informações do balanço, que tem periodicidade anual, no arquivo da vale </p>
# <hr>

# %% [markdown]
# <h4> <font color='purple'> Criando uma conta na nasdaq para extrair informacoes do iron ore
# tambem vamos extrair a cotacao do dolar e informacoes de balanco da yfinance</h4>
