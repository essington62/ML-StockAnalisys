# %%
import nasdaqdatalink

# %%
mydata = nasdaqdatalink.get("FRED/GDP")

# %%
mydata
# Out:
#                 Value
# Date
# 1947-01-01    243.164
# 1947-04-01    245.968
# 1947-07-01    249.585
# 1947-10-01    259.745
# 1948-01-01    265.742
# ...               ...
# 2020-10-01  21477.597
# 2021-01-01  22038.226
# 2021-04-01  22740.959
# 2021-07-01  23202.344
# 2021-10-01  23992.355
#
# [300 rows x 1 columns]

# %%
mydata1 = nasdaqdatalink.get("FRED/GDP", start_date="2001-12-31", end_date="2005-12-31")
mydata1
# Out:
#                 Value
# Date
# 2002-01-01  10783.500
# 2002-04-01  10887.460
# 2002-07-01  10984.040
# 2002-10-01  11061.433
# 2003-01-01  11174.129
# 2003-04-01  11312.766
# 2003-07-01  11566.669
# 2003-10-01  11772.234
# 2004-01-01  11923.447
# 2004-04-01  12112.815
# 2004-07-01  12305.307
# 2004-10-01  12527.214
# 2005-01-01  12767.286
# 2005-04-01  12922.656
# 2005-07-01  13142.642
# 2005-10-01  13324.204

# %%
mydata2 = nasdaqdatalink.get_table('ZACKS/FC', ticker='AAPL')
mydata2
# Out:
# ---------------------------------------------------------------------------
# ForbiddenError                            Traceback (most recent call last)
# c:\Users\edmun\anaconda3\envs\mlStocks\vale3\ML-StockAnalisys\nasdaq-api.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/edmun/anaconda3/envs/mlStocks/vale3/ML-StockAnalisys/nasdaq-api.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> mydata2 = nasdaqdatalink.get_table('ZACKS/FC', ticker='AAPL')
#       <a href='vscode-notebook-cell:/c%3A/Users/edmun/anaconda3/envs/mlStocks/vale3/ML-StockAnalisys/nasdaq-api.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> mydata2
#
# File c:\Users\edmun\anaconda3\envs\mlStocks\lib\site-packages\nasdaqdatalink\get_table.py:19, in get_table(datatable_code, **options)
#      17 while True:
#      18     next_options = copy.deepcopy(options)
# ---> 19     next_data = Datatable(datatable_code).data(params=next_options)
#      21     if data is None:
#      22         data = next_data
#
# ...
